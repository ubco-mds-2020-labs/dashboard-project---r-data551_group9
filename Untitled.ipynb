# %%
library(dash)
library(dashCoreComponents)
library(dashHtmlComponents)
library(dashBootstrapComponents)
library(ggplot2)
library(dplyr)
library(plotly)

hr1 <- read.csv("hr1.csv")
hr2 <- read.csv("hr2.csv")
hr3 <- read.csv("hr3.csv")
hr4 <- read.csv("hr4.csv")
options = hr2$company_size %>%
    unique %>%
    purrr::map(function(col) list(label = col, value = col))
options
data2 <- list(options[1], options[3], options[7], options[2], options[8], options[9], options[6], options[5], options[4])
options[c(1,3,7,2,8,9,6,5,4)]
# Out:
# [[1]]
# [[1]]$label
# [1] "no experience"
#
# [[1]]$value
# [1] "no experience"
#
#
# [[2]]
# [[2]]$label
# [1] "50-99"
#
# [[2]]$value
# [1] "50-99"
#
#
# [[3]]
# [[3]]$label
# [1] "<10"
#
# [[3]]$value
# [1] "<10"
#
#
# [[4]]
# [[4]]$label
# [1] "10000+"
#
# [[4]]$value
# [1] "10000+"
#
#
# [[5]]
# [[5]]$label
# [1] "5000-9999"
#
# [[5]]$value
# [1] "5000-9999"
#
#
# [[6]]
# [[6]]$label
# [1] "1000-4999"
#
# [[6]]$value
# [1] "1000-4999"
#
#
# [[7]]
# [[7]]$label
# [1] "10-49"
#
# [[7]]$value
# [1] "10-49"
#
#
# [[8]]
# [[8]]$label
# [1] "100-500"
#
# [[8]]$value
# [1] "100-500"
#
#
# [[9]]
# [[9]]$label
# [1] "500-999"
#
# [[9]]$value
# [1] "500-999"
# [[1]]
# [[1]]$label
# [1] "no experience"
#
# [[1]]$value
# [1] "no experience"
#
#
# [[2]]
# [[2]]$label
# [1] "<10"
#
# [[2]]$value
# [1] "<10"
#
#
# [[3]]
# [[3]]$label
# [1] "10-49"
#
# [[3]]$value
# [1] "10-49"
#
#
# [[4]]
# [[4]]$label
# [1] "50-99"
#
# [[4]]$value
# [1] "50-99"
#
#
# [[5]]
# [[5]]$label
# [1] "100-500"
#
# ...
